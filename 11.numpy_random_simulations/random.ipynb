# %% [markdown]
# # ~~Chaos~~
#
# # Random
# picture with chaos

# %% [markdown]
# Slides about random

# %% [markdown]
# ## Random
# Not very interesting, because ... wait for the next slide)

# %%
import random


random.randint(0, 10)
# Out:
# 1

# %% [markdown]
# ## Random in np
# Better cause can produce large random arrays

# %%
import numpy as np

# %%
# Uniformly distributed
# At least 1 argument - ceiling
np.random.randint(5)
# Out:
# 2

# %%
# From to
np.random.randint(-5, 5)
# Out:
# -4

# %%
# Several values
np.random.randint(-5, 6, 10)
# Out:
# array([ 0,  3,  5,  5,  4, -2, -4,  2,  2,  5])

# %%
# Uniformly distributed floats
np.random.random()
# Out:
# 0.943104668696257

# %% [markdown]
# ## Different distributions

# %%
# Normal
np.random.randn(2, 3)
# Out:
# array([[-0.30303934,  0.39839465, -0.48802327],
#        [ 0.79074641,  2.01141451,  0.92467618]])

# %%
# Have 2 distribution parameters
np.random.beta(1, 2, (2, 3))
# Out:
# array([[0.04100369, 0.45135484, 0.61265842],
#        [0.89379879, 0.67421185, 0.80170757]])

# %%
# Again 2 parameters
np.random.binomial(10, 0.3)
# Out:
# 4

# %%
# 1 parameter
np.random.pareto(3)
# Out:
# 0.7120484442254971

# %%
# Normal distribution with arbitrary mean and variance, which are defaulted to 0 and 1
np.random.normal(3, 0.1, 3)
# Out:
# array([3.07348849, 2.88520331, 3.16730714])

# %%
# df parameter
np.random.chisquare(5)
# Out:
# 3.391598378778647

# %%
# lambda parameter
np.random.poisson(3)
# Out:
# 5

# %%
# Another parameter
np.random.power(3)
# Out:
# 0.5101895579233388

# %% [markdown]
# ## Distribution illustration

# %%
import matplotlib.pyplot as plt
import seaborn as sns


plt.figure(figsize=(12, 8))
sns.distplot(np.random.power(0.3, 100))

# %% [markdown]
# ## Collections functions
# Really handy when you need them

# %%
numbers = [0, 1, 2, 4, 5, 6, 8, 10, 11]

# %%
# Change the order of the elements
# inplace
np.random.shuffle(numbers)

# %%
numbers
# Out:
# [2, 0, 5, 6, 8, 11, 10, 1, 4]

# %%
numbers
# Out:
# [2, 0, 5, 6, 8, 11, 10, 1, 4]

# %%
# Don't change original array, return copy
np.random.permutation(numbers)
# Out:
# array([10,  8, 11,  0,  5,  4,  6,  2,  1])

# %%
numbers
# Out:
# [2, 0, 5, 6, 8, 11, 10, 1, 4]

# %%
# Sample from the collection
np.random.choice(numbers)
# Out:
# 6

# %%
# Many elements
np.random.choice(numbers, 5)
# Out:
# array([ 6,  5,  6,  8, 11])

# %%
# Use each element once
np.random.choice(numbers, 5, replace=False)
# Out:
# array([ 2,  0, 10,  1,  8])

# %%
# Use custom probability of rolling for each element
np.random.choice(numbers, 
                 5, 
                 replace=False, 
                 p=[0.1316098 , 0.07381153, 0.03022185, 0.19347025, 0.14968923, 
                    0.12112077, 0.17881221, 0.10049474, 0.02076963])
# Out:
# array([10,  8,  1,  5,  4])

# %%
import matplotlib.pyplot as plt

# %%
0.784 * 4
# Out:
# 3.136

# %%
appropriate / 1000
# Out:
# 0.805

# %%
c = plt.Circle((0, 0), 1, alpha=0.6)

plt.figure(figsize=(8, 8))
fig = plt.gcf()
ax = fig.gca()

ax.add_artist(c)

plt.xlim(0, 1)
plt.ylim(0, 1)

x, y = np.random.rand(2, 10000)
plt.scatter(x, y, c='orange', marker='.')

# %%
(x < 1e-4).sum()
# Out:
# 12

# %%
appropriate
# Out:
# 78532

# %%
appropriate = (x ** 2 + y ** 2 <= 1).sum()
s = appropriate / 100000
# Out:
# 0.78532

# %% [markdown]
# $$S = \frac {\pi \cdot r ^ 2} {4}$$
#
# $$\pi = \frac {4 \cdot S} {r ^ 2}$$
#
# $$S = \frac {points\_in\_circle} {all\_points}$$

# %%
4 * s
# Out:
# 3.14128

# %% [markdown]
# $$\pi = \frac {4 \cdot 0.78532} {1 ^ 2}$$
# $$\pi = 3.14128$$
